# %%
# mount data from drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/Shareddrives/CS247-Project/GMAN-master/PeMS'
# Out:
# /content/drive/Shareddrives/CS247-Project/GMAN-master/PeMS

# %%
# !python3 train.py
# Out:
# 2021-06-01 08:29:00.240001: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# K=8, L=1, P=12, Q=12, SE_file='data/SE(PeMS).txt', batch_size=32, d=8, decay_epoch=5, learning_rate=0.001, log_file='data/log(PeMS)', max_epoch=50, model_file='data/GMAN(PeMS)', patience=10, test_ratio=0.2, time_slot=5, traffic_file='data/PeMS_7_converted.h5', train_ratio=0.7, val_ratio=0.1
# loading data...
# ...

# %%
# !python3 test.py
# Out:
# 2021-06-01 16:38:29.048880: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# P=12, Q=12, SE_file='data/SE(PeMS).txt', batch_size=32, log_file='data/log(PeMS)', model_file='data/GMAN(PeMS)', test_ratio=0.2, traffic_file='data/PeMS.h5', train_ratio=0.7, val_ratio=0.1
# loading data...
# ...
